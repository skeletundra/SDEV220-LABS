# %%
# %%writefile zoo.py
def hours():
    print('Open 9-5 daily')
# Out:
# Writing zoo.py

# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 daily

# %%
import zoo as menagerie
menagerie.hours()
# Out:
# Open 9-5 daily

# %%
from sqlalchemy import create_engine, text

engine = create_engine('sqlite:///:memory:')

with engine.connect() as conn:
    conn.execute(text("CREATE TABLE book (id INTEGER PRIMARY KEY, title TEXT)"))
    conn.execute(text("""
        INSERT INTO book (title) VALUES
        ('The Great Gatsby'),
        ('1984'),
        ('Brave New World'),
        ('Catch-22')
    """))
    
    result = conn.execute(text("SELECT title FROM book ORDER BY title"))
    for row in result:
        print(row.title)
# Out:
# 1984
# Brave New World
# Catch-22
# The Great Gatsby
