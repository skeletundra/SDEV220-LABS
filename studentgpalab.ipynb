# %%
# -----
# Isaiah Flores
# studentgpalab.ipynb
#This program accepts the first name, last name, and GPA of a student.
#It then checks if the student qualifies for the Dean's list or Honor roll.
#The program will process records until the user enters ZZZ as a last name.
# -----

while True:
    last_name = input("Enter student's last name (or ZZZ to quit): ")

    if last_name.upper() == 'ZZZ':
        break

    first_name = input("Enter student's first name: ")

    try:
        gpa = float(input("Enter student's GPA: "))
    except ValueError:
        print("Invalid Input. GPA must be a number.")
        continue

    if gpa >= 3.5:
        print(f"{first_name} {last_name} qualifies for the Dean's List.\n")
    elif gpa >= 3.25:
        print(f"{first_name} {last_name} qualifies for Honor Roll.\n")
    else:
        print(f"{first_name} {last_name} did not qualify for any honors.\n")
# Out:
# Enter student's last name (or ZZZ to quit):  Doe
# Enter student's first name:  John
# Enter student's GPA:  3.5
# John Doe qualifies for the Dean's List.
# Enter student's last name (or ZZZ to quit):  Smith
# Enter student's first name:  Joe
# Enter student's GPA:  3.4
# Joe Smith qualifies for Honor Roll.
# Enter student's last name (or ZZZ to quit):  Baker
# Enter student's first name:  Jack
# Enter student's GPA:  4.0
# Jack Baker qualifies for the Dean's List.
# Enter student's last name (or ZZZ to quit):  Smith
# Enter student's first name:  Bob
# Enter student's GPA:  2.5
# Bob Smith did not qualify for any honors.
# Enter student's last name (or ZZZ to quit):  Miller
# Enter student's first name:  Jake
# Enter student's GPA:  3.0
# Jake Miller did not qualify for any honors.
# Enter student's last name (or ZZZ to quit):  ZZZ
